# %% [markdown]
# Analysis and Visualization of Complex Data
#
# CREMILDO RIBA GOUVEIA DIAS
#
# Exercise 02 - Best charts to represent different data or dataset types.
#
# Each type of data or datasets is best visualized by certain kinds of charts, depending on both the targeted audience as well
# as the personal preferences of the data visualizer. In this exercise you will first simulate different types of data and datasets
# in python. Randomizations are usefull to understand certain statistical concepts and also as a basis for random sampling, which may
# be required when dealing with big data. Based on these simulated data, the exercise will consist on choosing the type of chart that you find more adequate to represent the different types of data and datasets.
#
# The objectives of this exercise are to:
# 1. identify each type of variables and tables that were created.
#
# 2. try your best to interpret each line of the code provided by inserting a note in front of each line (it might be usefull to create a jupiter notebook from the markdown file)
#
# 2. based on these simulated data, draw sketches of the charts that you find more adequate to represent the different types of data and datasets. You should identify the different axis of the plot, if applicable.
#
# You will use two modules that provide pseudo-random number generators to implement random sampling routines. Have a look [here](https://docs.python.org/3/library/random.html) (random module) and [here](https://numpy.org/doc/stable/reference/random/index.html) (numpy.random module). Both allow to simulate data and take random samples, although np.random allows more pseudo-random generator methods to be implemented.
#
# To run the simulations, you should first import pandas, numpy and random modules (in case you still did not installed these modules, you will need to install beforehand).

# %% [markdown]
# Importar pacotes

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import re

# %% [markdown]
# Simulate var1

# %%
var1 = []
random.seed(30) # optional: used to fix the seed of the pseudo-random number generator (use any number of your choice)
levels = ["Permanent crops", "Irrigated crops", "Managed Forest", "Natural Forest", "Agro-Forestry system", "Urban", "Pasture", "Shrubland" ]
for _ in range(100): # why is a loop needed?
    var1 += random.sample(levels, 1) # var1.append(random.sample(levels, 1)) would also work
    
print("With list:" , random.sample(levels, 1))
print (var1)
# var1 é uma variavel qualitativa nominal
# Out:
# With list: ['Shrubland']
# ['Agro-Forestry system', 'Permanent crops', 'Natural Forest', 'Agro-Forestry system', 'Permanent crops', 'Pasture', 'Pasture', 'Managed Forest', 'Irrigated crops', 'Shrubland', 'Permanent crops', 'Natural Forest', 'Permanent crops', 'Irrigated crops', 'Managed Forest', 'Pasture', 'Urban', 'Irrigated crops', 'Pasture', 'Permanent crops', 'Natural Forest', 'Agro-Forestry system', 'Pasture', 'Irrigated crops', 'Agro-Forestry system', 'Irrigated crops', 'Shrubland', 'Agro-Forestry system', 'Managed Forest', 'Agro-Forestry system', 'Agro-Forestry system', 'Agro-Forestry system', 'Irrigated crops', 'Managed Forest', 'Natural Forest', 'Urban', 'Irrigated crops', 'Permanent crops', 'Pasture', 'Agro-Forestry system', 'Managed Forest', 'Managed Forest', 'Shrubland', 'Urban', 'Shrubland', 'Urban', 'Urban', 'Irrigated crops', 'Permanent crops', 'Irrigated crops', 'Shrubland', 'Shrubland', 'Agro-Forestry system', 'Shrubland', 'Agro-Forestry system', 'Agro-Forestry system', 'Managed Forest', 'Managed Forest', 'Managed Forest', 'Agro-Forestry system', 'Pasture', 'Natural Forest', 'Natural Forest', 'Shrubland', 'Urban', 'Pasture', 'Agro-Forestry system', 'Pasture', 'Pasture', 'Agro-Forestry system', 'Shrubland', 'Urban', 'Agro-Forestry system', 'Managed Forest', 'Managed Forest', 'Agro-Forestry system', 'Urban', 'Permanent crops', 'Natural Forest', 'Irrigated crops', 'Urban', 'Permanent crops', 'Agro-Forestry system', 'Pasture', 'Permanent crops', 'Shrubland', 'Permanent crops', 'Managed Forest', 'Shrubland', 'Urban', 'Agro-Forestry system', 'Shrubland', 'Managed Forest', 'Managed Forest', 'Pasture', 'Irrigated crops', 'Urban', 'Permanent crops', 'Natural Forest', 'Pasture']

# %% [markdown]
# Simulate var2

# %%
np.random.seed(30) # optional: used to fix the seed of the pseudo-random number generator (use any number of your choice)
var2 = np.random.uniform(0, 100, 100)

print (var2)
# var2 é uma variavel quantitativa contínua
# Out:
# [64.41435361 38.07484896 66.30479053 16.36507261 96.26078137 34.66618404
#  99.17509923 23.50578956 58.56942685 40.66901016 13.6234322  54.41362876
#  51.81763468 76.68551063 93.38501433  8.97033828 19.57712568 99.41936843
#  23.51804976 23.89863719 62.90998308 73.49525766 68.83443831  3.11307484
#  90.25138432 28.64353279 55.56125638 37.64202445  2.66243648 49.41491215
#  83.47150935 36.698733   51.53821122 47.23791254 38.61520885 74.41370044
#  33.52420797 59.54382882 31.61333819 34.62504239 24.48318085 69.7950165
#  21.20808314 26.72931683 37.38940787 57.30885068 91.73580787 81.89759368
#  16.31808924  2.41547699 78.46536272 26.4857379  33.93670564 81.43695851
#  80.74547159 49.35616368 84.53124439 36.51899844  4.78308992 26.41457864
#  46.38671601 69.33550595 31.34367534 46.25367885 81.96876527 68.44910251
#  32.40338238 57.68119991 63.26499838 59.64616676 13.78268795 61.80010238
#  49.3463693  14.36121248  3.08218913 93.91557278 25.68377152  5.7134603
#  38.77082245 35.70967475 98.6384143  93.95906373 58.27752236 99.31031338
#  98.99145005 86.50563741 16.17182285 36.84902405 30.67266599 34.0863243
#  29.04777477 63.78640728  5.06540029 93.51843107  2.58448369 53.16390522
#   7.16037946 69.14944386 11.70875118 19.35125077]

# %% [markdown]
# Simulate table1

# %%
table1 = pd.DataFrame(var1).value_counts(sort=True)
table1 = table1.rename_axis("landuse")
table1 = table1.reset_index(name="Frequency")

print(table1)
# table1 tem duas variéveis a lanuse (qualitativa nominal) e a frequency (quantitativa discreta)
#Proposta do grafico: diagrama de barras e/ou em forma circular (Pie)
# Out:
#                 landuse  Frequency
# 0  Agro-Forestry system         19
# 1        Managed Forest         14
# 2               Pasture         13
# 3       Permanent crops         12
# 4             Shrubland         12
# 5       Irrigated crops         11
# 6                 Urban         11
# 7        Natural Forest          8

# %% [markdown]
# Criação de grafico de barras

# %%
x_axis = np.array(["Agro-Forestry system", "Managed Forest", "Pasture", "Permanent crops","Shrubland","Irrigated crops", "Urban","Natural Forest"])
y_axis = np.array([19, 14, 13, 12, 12, 11, 11, 8])

plt.barh(x_axis, y_axis, color = "#00FF33", height = 0.4)
plt.xlabel("Frequency")
plt.ylabel("Land Use")
plt.title(" Land Use Land Cover 2023")
plt.show()

# %% [markdown]
# Criação de grafico circular

# %%
from matplotlib import pyplot as plt 
import numpy as np
landuse1 = ["Agro-Forestry system", "Managed Forest", "Pasture", "Permanent crops","Shrubland","Irrigated crops", "Urban","Natural Forest"] 
  
data = [19, 14, 13, 12, 12, 11, 11, 8]
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = landuse1, autopct="%1.1f%%") 
plt.title(" Land Use Land Cover 2023") 
plt.show()

# %% [markdown]
# Simulate table2

# %%
table2 = pd.DataFrame(list(zip(var1, var2)), columns = ["landuse", "cover"])
# Note: The zip() function returns a zip object, which is an iterator of tuples where the first item in each passed 
# iterator is paired together, and then the second item in each passed iterator are paired together, etc. The tuple() 
# function displays a readable version of the result - try running: print(tuple(zip(var1,var2)))
print(table2)
print(tuple(zip(var1,var2)))

# table2 tem duas variéveis a lanuse (qualitativa nominal) e a cover (quantitativa continua)
#Proposta do grafico: diagrama de barras e/boxplot
# Out:
#                  landuse      cover
# 0   Agro-Forestry system  64.414354
# 1        Permanent crops  38.074849
# 2         Natural Forest  66.304791
# 3   Agro-Forestry system  16.365073
# 4        Permanent crops  96.260781
# ..                   ...        ...
# 95       Irrigated crops  53.163905
# 96                 Urban   7.160379
# 97       Permanent crops  69.149444
# 98        Natural Forest  11.708751
# 99               Pasture  19.351251
#
# [100 rows x 2 columns]
# (('Agro-Forestry system', 64.4143536068335), ('Permanent crops', 38.074848963511656), ('Natural Forest', 66.30479053356686), ('Agro-Forestry system', 16.365072610275334), ('Permanent crops', 96.26078136743187), ('Pasture', 34.666184037976564), ('Pasture', 99.17509922936077), ('Managed Forest', 23.505789560564562), ('Irrigated crops', 58.569426852165776), ('Shrubland', 40.66901016252007), ('Permanent crops', 13.623432201904695), ('Natural Forest', 54.413628763817975), ('Permanent crops', 51.81763468258455), ('Irrigated crops', 76.68551062985054), ('Managed Forest', 93.38501433185797), ('Pasture', 8.970338278592749), ('Urban', 19.577125677002506), ('Irrigated crops', 99.41936842973615), ('Pasture', 23.51804976169889), ('Permanent crops', 23.898637194265106), ('Natural Forest', 62.9099830827202), ('Agro-Forestry system', 73.49525766431395), ('Pasture', 68.83443830672039), ('Irrigated crops', 3.1130748417627196), ('Agro-Forestry system', 90.2513843248535), ('Irrigated crops', 28.643532791235426), ('Shrubland', 55.561256380610956), ('Agro-Forestry system', 37.64202445295432), ('Managed Forest', 2.662436477311436), ('Agro-Forestry system', 49.41491215472047), ('Agro-Forestry system', 83.47150934934146), ('Agro-Forestry system', 36.69873300102526), ('Irrigated crops', 51.538211224090816), ('Managed Forest', 47.23791254252798), ('Natural Forest', 38.615208845684734), ('Urban', 74.41370044402956), ('Irrigated crops', 33.5242079666205), ('Permanent crops', 59.54382882010286), ('Pasture', 31.61333819082539), ('Agro-Forestry system', 34.62504239281453), ('Managed Forest', 24.483180845708308), ('Managed Forest', 69.7950164982001), ('Shrubland', 21.208083139141454), ('Urban', 26.729316832645942), ('Shrubland', 37.38940787175279), ('Urban', 57.30885067829343), ('Urban', 91.73580787188014), ('Irrigated crops', 81.89759367549159), ('Permanent crops', 16.318089235945177), ('Irrigated crops', 2.4154769854872082), ('Shrubland', 78.46536271628383), ('Shrubland', 26.485737895719865), ('Agro-Forestry system', 33.93670563513426), ('Shrubland', 81.43695851106332), ('Agro-Forestry system', 80.74547158600521), ('Agro-Forestry system', 49.35616367989356), ('Managed Forest', 84.53124438835712), ('Managed Forest', 36.51899843900238), ('Managed Forest', 4.783089915143068), ('Agro-Forestry system', 26.41457863972352), ('Pasture', 46.386716011853856), ('Natural Forest', 69.33550594970708), ('Natural Forest', 31.343675340085888), ('Shrubland', 46.25367885188232), ('Urban', 81.96876526858328), ('Pasture', 68.44910250996779), ('Agro-Forestry system', 32.403382380566285), ('Pasture', 57.68119991495879), ('Pasture', 63.26499837913755), ('Agro-Forestry system', 59.6461667566541), ('Shrubland', 13.782687945281946), ('Urban', 61.80010238283985), ('Agro-Forestry system', 49.346369302049574), ('Managed Forest', 14.361212477861496), ('Managed Forest', 3.082189126169621), ('Agro-Forestry system', 93.91557277828893), ('Urban', 25.683771524633404), ('Permanent crops', 5.713460300902695), ('Natural Forest', 38.770822445994334), ('Irrigated crops', 35.70967475164035), ('Urban', 98.63841429851597), ('Permanent crops', 93.95906372601995), ('Agro-Forestry system', 58.27752235696255), ('Pasture', 99.31031337764242), ('Permanent crops', 98.99145005412969), ('Shrubland', 86.50563741225072), ('Permanent crops', 16.17182284919555), ('Managed Forest', 36.84902404813931), ('Shrubland', 30.672665985307447), ('Urban', 34.08632429762164), ('Agro-Forestry system', 29.047774765337053), ('Shrubland', 63.7864072795333), ('Managed Forest', 5.065400291446586), ('Managed Forest', 93.5184310731547), ('Pasture', 2.5844836873522903), ('Irrigated crops', 53.163905223649486), ('Urban', 7.160379461879806), ('Permanent crops', 69.14944386424239), ('Natural Forest', 11.708751182458943), ('Pasture', 19.351250766628812))

# %%
import seaborn as sns

sns.barplot(data=table2, x="cover", y="landuse")
plt.title(" Land Use Land Cover 2023")
plt.show()

# %% [markdown]
# Criar boxplot

# %%
sns.set(rc={'figure.figsize': (16, 6)})
sns.violinplot(data=table2, x="landuse", y="cover")
plt.title(" Land Use Land Cover 2023")
# Out:
# Text(0.5, 1.0, ' Land Use Land Cover 2023')

# %% [markdown]
# Simulate table3

# %%
np.random.seed(30) # optional: used to fix the seed of the pseudo-random number generator (use any number of your choice)
year = list(range(1970,2021))
temp = np.random.normal(17,2,51)
table3 = pd.DataFrame(list(zip(year, temp)), columns = ["Year", "Temperature"])
print(table3)
#table3 tem duas variaveias quantitativas sendo Year (Discreta) e Temperature (Contínua)
#Proposta do grafico: grafico de linha para serie temporal
# Out:
#     Year  Temperature
# 0   1970    14.471895
# 1   1971    20.055811
# 2   1972    15.058578
# 3   1973    17.941119
# 4   1974    16.798607
# 5   1975    17.607586
# 6   1976    13.548075
# 7   1977    20.170191
# 8   1978    17.268593
# 9   1979    14.786289
# 10  1980    20.156451
# 11  1981    17.214996
# 12  1982    15.471904
# 13  1983    15.449623
# 14  1984    19.767694
# 15  1985    18.520770
# 16  1986    16.428709
# 17  1987    18.076735
# 18  1988    12.832207
# 19  1989    18.875563
# 20  1990    16.988444
# 21  1991    16.065042
# 22  1992    16.153969
# 23  1993    19.128964
# 24  1994    11.193265
# 25  1995    20.233781
# 26  1996    19.851020
# 27  1997    15.670490
# 28  1998    18.970036
# 29  1999    13.599069
# 30  2000    14.799712
# 31  2001    14.368712
# 32  2002    18.621002
# 33  2003    14.910443
# 34  2004    15.621541
# 35  2005    15.294486
# 36  2006    19.226944
# 37  2007    13.157661
# 38  2008    15.597195
# 39  2009    18.698176
# 40  2010    19.101400
# 41  2011    15.926251
# 42  2012    16.941615
# 43  2013    19.788112
# 44  2014    16.204265
# 45  2015    19.038255
# 46  2016    20.797763
# 47  2017    16.290301
# 48  2018    16.225967
# 49  2019    13.145389
# 50  2020    18.101513

# %% [markdown]
# Criar grafico de serie temporal

# %%
sns.set(rc={'figure.figsize': (12, 5)})
sns.lineplot(data=table3, x="Year", y="Temperature", markers=False)
plt.title(" Variação de temperatura 51 anos ")
# Out:
# Text(0.5, 1.0, ' Variação de temperatura 51 anos ')

# %% [markdown]
# Simulate table4

# %%
xx = np.array([16,21])
yy = np.array([300, 1200])
means = [xx.mean(), yy.mean()]  
stds = [xx.std() / 3, yy.std() / 3]
corr = -0.7 # correlation
covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] # covariance matrix
table4 = pd.DataFrame(np.random.multivariate_normal(means, covs, 100), columns = ["Mean Anual Temperature", "Total Precipitation"])

print(table4)
#table4 tem duas variaveias quantitativas (Mean Anual Temperature and Total Precipitation)
#Proposta do grafico: grafico de linha
# Out:
#     Mean Anual Temperature  Total Precipitation
# 0                18.409122           893.155184
# 1                20.285113           481.017189
# 2                17.696110          1006.162779
# 3                18.386298           601.222149
# 4                17.570984           746.796074
# ..                     ...                  ...
# 95               19.428097           539.416609
# 96               19.168021           812.049724
# 97               17.881733           731.619124
# 98               18.325172           763.356841
# 99               19.155235           760.722083
#
# [100 rows x 2 columns]

# %% [markdown]
# Criar grafico de linha

# %%
sns.lineplot(data=table4, x="Mean Anual Temperature", y="Total Precipitation",markers=True, dashes=True)
# Out:
# <Axes: xlabel='Mean Anual Temperature', ylabel='Total Precipitation'>

# %% [markdown]
# table5

# %%
col1 = pd.Series(list(range(1900,2010,10))).repeat(8)
col2 = ["Permanent crops", "Irrigated crops", "Managed Forest", "Natural Forest", "Agro-Forestry system", "Urban", "Pasture", "Shrubland" ]*11
col3 = np.random.uniform(0, 100, 90)
table5 = pd.DataFrame(list(zip(col1, col2, col3)), columns = ["Year", "Landuse", "Cover"])

print(table5)
#table3 tem três variaveias sendo uma qualitativa [Landuse (nominal)] e duas quantitativas  [Year (Discreta) e cover (Contínua)]
#Proposta do grafico: grafico de calor
# Out:
#     Year               Landuse      Cover
# 0   1900       Permanent crops  46.474214
# 1   1900       Irrigated crops  83.242465
# 2   1900        Managed Forest  29.676873
# 3   1900        Natural Forest  35.158949
# 4   1900  Agro-Forestry system  99.894214
# ..   ...                   ...        ...
# 83  2000        Natural Forest  11.388013
# 84  2000  Agro-Forestry system  68.831696
# 85  2000                 Urban  97.240440
# 86  2000               Pasture  72.663993
# 87  2000             Shrubland  46.625148
#
# [88 rows x 3 columns]

# %% [markdown]
# Criação de grafico de calor

# %%
table5=table5.pivot('Year','Landuse','Cover')
fig, ax = plt.subplots (figsize=(6, 7))
sns.heatmap(table5, annot=table5.rank(axis="columns"), linewidths = .3)
# Out:
# C:\Users\isa12\AppData\Local\Temp\ipykernel_10892\4278809707.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   table5=table5.pivot('Year','Landuse','Cover')
# <Axes: xlabel='Landuse', ylabel='Year'>
